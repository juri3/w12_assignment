# %% [markdown]
# **Crawling_Jobkorea**

# %%
import pandas as pd
import numpy as np

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support.ui import WebDriverWait
from bs4 import BeautifulSoup


service = Service(executable_path=ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

url_jobkor = 'https://www.jobkorea.co.kr/Search/?stext='+'데이터분석'


#############################잡코리아
driver.get(url_jobkor)

# 기다려달라는 값을 전달 : 최대 10초 기다리기
wait = WebDriverWait(driver, 10)
wait.until(EC.presence_of_element_located((By.CSS_SELECTOR, "div[data-sentry-component='JobList']")))


# 드라이버 접근 > 페이지 소스 가져오기
html_jobkor = driver.page_source
soup_jobkor = BeautifulSoup(html_jobkor, 'html.parser')

# 드라이버 종료(필수)
driver.quit()

# %%
site_list = []
companys_list = []
recruits_list = []
detail_list = []
url_list = []

items= soup_jobkor.select_one("div[data-sentry-component='JobList']").select("div[data-sentry-component='CardCommon']")
for item in items:
    item_divide = item.select_one("div[data-sentry-element='Block']").select("div[data-sentry-source-file='index.tsx']")
    
    site_list.append("Job_Korea")

    company = item_divide[3].select_one('a[data-sentry-element="BaseLink"]:not([data-sentry-component="Title"]) span')
    companys_list.append(company.get_text(strip=True) if company else None) 
    # print(companys_list)
    
    recruit = item_divide[4].select_one('a[data-sentry-element="BaseLink"][data-sentry-component="Title"]')
    recruits_list.append(recruit.get_text(strip=True) if recruit else None) 
    # print(recruits_list)

    url_list.append(recruit["href"] if recruit else None)
    # print(url_list)

    detail = item_divide[6].select_one("div.Flex_display_flex__i0l0hl2.Flex_direction_column__i0l0hl4 div[class*='Flex_gap_space16'][class*='Flex_direction_row']")
    detail_items = [sp.get_text(strip=True) for sp in detail]
    detail_list.append(detail_items)
    # print(detail_list)

# %%
data = {
    "Site": site_list,
    "Col_Company": companys_list,
    "Col_Recruit": recruits_list,
    "Col_detail": detail_list,
    "Col_url": url_list,
}

df = pd.DataFrame(data)
display(df)

df.to_csv("data_tmp/data_jobkorea.csv", encoding="utf-8-sig")
# Out:
#          Site              Col_Company  \
# 0   Job_Korea                   ㈜원익피앤이
# 1   Job_Korea              콘센트릭스서비스코리아
# 2   Job_Korea              콘센트릭스서비스코리아
# 3   Job_Korea                    ㈜지바이크
# 4   Job_Korea                  넛지헬스케어㈜
# 5   Job_Korea                   ㈜메디쿼터스
# 6   Job_Korea                  넛지헬스케어㈜
# 7   Job_Korea                    삼양식품㈜
# 8   Job_Korea       ㈜트리노드(TreenodInc.)
# 9   Job_Korea                ㈜에이치엔비아시아
# 10  Job_Korea                   ㈜디지토피아
# 11  Job_Korea                   휴먼교육센터
# 12  Job_Korea                      SK㈜
# 13  Job_Korea                     ㈜컴투스
# 14  Job_Korea                    마이데이터
# 15  Job_Korea                 ㈜테크핀레이팅스
# 16  Job_Korea               (주)에이치에스애드
# 17  Job_Korea                     민컴퍼니
# 18  Job_Korea                 ㈜파오스파트너스
# 19  Job_Korea  피디에프솔루션세미컨덕터테크놀로지코리아(유)
#
#                                           Col_Recruit  \
# 0                               [원익PNE]데이터분석및 솔루션 담당자
# 1                                 [Catalyst]데이터분석컨설턴트
# 2                                 [Catalyst]데이터분석컨설턴트
# 3                           [지쿠] 전략마케팅팀데이터분석전문가 경력 채용
# 4                           [캐시워크-병역특례]데이터분석담당 산업기능요원
# 5                          [일본:누구(nugu)] 프로덕트기획팀데이터분석
# 6                              [캐시워크]데이터분석담당 채용전환형 인턴
# 7                          [삼양식품] Global 물류(관리/데이터분석)
# 8                           [서울/경력 5년 이상]데이터분석팀데이터분석가
# 9                        전략기획 시스템 운영 및데이터분석담당 채용(대리급)
# 10                                [강남] 대용량데이터분석경험자 모집
# 11             [국비무료/숙식무료]AI/빅데이터분석/풀스택/KDT심화(무료숙식제공)
# 12                     IIoT 기반 진단모니터링 구축 및데이터분석전문가 영입
# 13                           [컴투스홀딩스]데이터분석담당자 (3-8년차)
# 14                                 데이터분석및 시각화 엔지니어 모집
# 15                                [신용평가사]데이터분석(5년 이상)
# 16                   2025년 하반기 대졸 채용연계형 인턴십 - AI데이터분석
# 17                                [강남] 대용량데이터분석경험자 모집
# 18                    (주)파오스파트너스 -DB관리, DB생성, DB분석 채용
# 19  (외국계 나스닥 상장) Spotfire, Data분석, AI/ML 경력 정규직 채용...
#
#                               Col_detail  \
# 0              [경력3년↑, 석사↑, 정규직, 경기 수원시]
# 1             [경력5년↑, 학력무관, 정규직, 서울 강남구]
# 2             [경력5년↑, 학력무관, 정규직, 서울 강남구]
# 3              [경력3년↑, 대졸↑, 정규직, 서울 강남구]
# 4             [경력무관, 학력무관, 병역특례, 서울 강남구]
# 5            [경력10년↑, 학력무관, 정규직, 서울 강남구]
# 6                  [신입, 대졸↑, 인턴, 서울 강남구]
# 7              [경력8년↑, 대졸↑, 정규직, 서울 성북구]
# 8             [경력5년↑, 학력무관, 정규직, 서울 강남구]
# 9              [경력2년↑, 대졸↑, 정규직, 서울 송파구]
# 10       [경력8년↑, 초대졸↑, 프리랜서, 서울 금천구 외 1]
# 11  [신입·경력, 학력무관, 연수생/교육생, 서울 영등포구 외 14]
# 12             [경력5년↑, 대졸↑, 정규직, 경기 성남시]
# 13            [경력3년↑, 학력무관, 정규직, 서울 금천구]
# 14           [경력8년↑, 학력무관, 프리랜서, 서울 서초구]
# 15              [경력5년↑, 대졸↑, 정규직, 서울 중구]
# 16                 [신입, 대졸↑, 인턴, 서울 마포구]
# 17   [경력10년↑, 초대졸↑, 계약직 외 1, 서울 마포구 외 1]
# 18             [경력무관, 초대졸↑, 정규직, 서울 용산구]
# 19              [경력무관, 석사↑, 정규직, 경기 성남시]
#
#                                               Col_url
# 0   https://www.jobkorea.co.kr/Recruit/GI_Read/476...
# 1   https://www.jobkorea.co.kr/Recruit/GI_Read/477...
# 2   https://www.jobkorea.co.kr/Recruit/GI_Read/475...
# 3   https://www.jobkorea.co.kr/Recruit/GI_Read/474...
# 4   https://www.jobkorea.co.kr/Recruit/GI_Read/474...
# 5   https://www.jobkorea.co.kr/Recruit/GI_Read/476...
# 6   https://www.jobkorea.co.kr/Recruit/GI_Read/474...
# 7   https://www.jobkorea.co.kr/Recruit/GI_Read/473...
# 8   https://www.jobkorea.co.kr/Recruit/GI_Read/476...
# 9   https://www.jobkorea.co.kr/Recruit/GI_Read/477...
# 10  https://www.jobkorea.co.kr/Recruit/GI_Read/477...
# 11  https://www.jobkorea.co.kr/Recruit/GI_Read/477...
# 12  https://www.jobkorea.co.kr/Recruit/GI_Read/474...
# 13  https://www.jobkorea.co.kr/Recruit/GI_Read/475...
# 14  https://www.jobkorea.co.kr/Recruit/GI_Read/477...
# 15  https://www.jobkorea.co.kr/Recruit/GI_Read/475...
# 16  https://www.jobkorea.co.kr/Recruit/GI_Read/476...
# 17  https://www.jobkorea.co.kr/Recruit/GI_Read/476...
# 18  https://www.jobkorea.co.kr/Recruit/GI_Read/476...
# 19  https://www.jobkorea.co.kr/Recruit/GI_Read/476...
